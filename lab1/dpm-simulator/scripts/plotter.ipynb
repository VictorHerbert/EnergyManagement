# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("../build/out.log")
df.head()
# Out:
#                file  timeout  energy_without_dpm  energy_with_dpm
# 0  workloads/w1.txt      0.0           29.879098         0.260785
# 1  workloads/w2.txt      0.0           30.138814         0.368555
# 2  workloads/w1.txt      2.0           29.879098         0.248981
# 3  workloads/w2.txt      2.0           30.138814         0.373914
# 4  workloads/w1.txt      4.0           29.879098         0.202201

# %%
dfs = [df[df['file'] == file] for file in df['file'].unique()]
dfs[0]
# Out:
#                  file  timeout  energy_without_dpm  energy_with_dpm
# 0    workloads/w1.txt      0.0           29.879098         0.260785
# 2    workloads/w1.txt      2.0           29.879098         0.248981
# 4    workloads/w1.txt      4.0           29.879098         0.202201
# 6    workloads/w1.txt      6.0           29.879098         0.202696
# 8    workloads/w1.txt      8.0           29.879098         0.203191
# ..                ...      ...                 ...              ...
# 190  workloads/w1.txt    190.0           29.879098         0.248253
# 192  workloads/w1.txt    192.0           29.879098         0.248748
# 194  workloads/w1.txt    194.0           29.879098         0.249243
# 196  workloads/w1.txt    196.0           29.879098         0.249738
# 198  workloads/w1.txt    198.0           29.879098         0.250233
#
# [100 rows x 4 columns]

# %%
plt.grid()
for file_df in dfs:
    plt.plot(file_df['timeout'], file_df['energy_with_dpm'])
